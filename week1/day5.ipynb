# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  'inference/get-started',
#  '/spaces',
#  '/models',
#  '/moonshotai/Kimi-K2-Instruct',
#  '/Qwen/Qwen3-235B-A22B-Instruct-2507',
#  '/Qwen/Qwen3-Coder-480B-A35B-Instruct',
#  '/mistralai/Voxtral-Mini-3B-2507',
#  '/HiDream-ai/HiDream-E1-1',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/black-forest-labs/FLUX.1-Kontext-Dev',
#  '/spaces/akhaliq/anycoder',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/NihalGazi/Text-To-Speech-Unlimited',
#  '/spaces',
#  '/datasets/NousResearch/Hermes-3-Dataset',
#  '/datasets/common-pile/caselaw_access_project',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/microsoft/rStar-Coder',
#  '/datasets/interstellarninja/hermes_reasoning_tool_use',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussions', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# moonshotai/Kimi-K2-Instruct
# Updated
# 1 day ago
# •
# 195k
# •
# 1.76k
# Qwen/Qwen3-235B-A22B-Instruct-2507
# Updated
# 2 days ago
# •
# 1.32k
# •
# 422
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# about 10 hours ago
# •
# 403
# mistralai/Voxtral-Mini-3B-2507
# Updated
# about 6 hours ago
# •
# 46.4k
# •
# 423
# HiDream-ai/HiDream-E1-1
# Updated
# 6 days ago
# •
# 180
# •
# 147
# Browse 1M+ models
# Spaces
# Running
# 10.7k
# 10.7k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# MCP
# 1.02k
# 1.02k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Running
# 2.32k
# 2.32k
# Anycoder
# 🏢
# Generate modern HTML/CSS/JS code for web apps
# Running
# on
# Zero
# MCP
# 1.28k
# 1.28k
# Wan2.1 Fast
# 🎥
# Generate animated videos from images
# Running
# 1.01k
# 1.01k
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# NousResearch/Hermes-3-Dataset
# Updated
# 12 days ago
# •
# 3.07k
# •
# 209
# common-pile/caselaw_access_project
# Updated
# Jun 6
# •
# 3.02k
# •
# 158
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 31.6k
# •
# 8.43k
# microsoft/rStar-Coder
# Updated
# 3 days ago
# •
# 5.38k
# •
# 131
# interstellarninja/hermes_reasoning_tool_use
# Updated
# about 7 hours ago
# •
# 275
# •
# 29
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 777 models
# •
# 3.66k followers
# AI at Meta
# Enterprise
# company
# •
# 2.18k models
# •
# 6.9k followers
# Amazon
# company
# •
# 20 models
# •
# 3.31k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 21.5k followers
# Intel
# company
# •
# 220 models
# •
# 2.75k followers
# Microsoft
# company
# •
# 409 models
# •
# 13.8k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 170 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,366
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,901
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,355
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,785
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,917
# Fast tokenizers optimized for research & production
# TRL
# 14,711
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,174
# State-of-the-art ML running directly in your browser
# smolagents
# 21,489
# Smol library to build great agents in Python
# PEFT
# 19,103
# Parameter-efficient finetuning for large language models
# Datasets
# 20,402
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,352
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,958
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# moonshotai/Kimi-K2-Instruct
# Updated
# 1 day ago
# •
# 195k
# •
# 1.76k
# Qwen/Qwen3-235B-A22B-Instruct-2507
# Updated
# 2 days ago
# •
# 1.32k
# •
# 422
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# about 10 hours ago
# •
# 403
# mistralai/Voxtral-Mini-3B-2507
# Updated
# about 6 hours ago
# •
# 46.4k
# •
# 423
# HiDream-ai/HiDream-E1-1
# Updated
# 6 days ago
# •
# 180
# •
# 147
# Browse 1M+ models
# Spaces
# Running
# 10.7k
# 10.7k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# MCP
# 1.02k
# 1.02k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Running
# 2.32k
# 2.32k
# Anycoder
# 🏢
# Generate modern HTML/CSS/JS code for web apps
# Running
# on
# Zero
# MCP
# 1.28k
# 1.28k
# Wan2.1 Fast
# 🎥
# Generate animated videos from images
# Running
# 1.01k
# 1.01k
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# NousResearch/Hermes-3-Dataset
# Updated
# 12 days ago
# •
# 3.07k
# •
# 209
# common-pile/caselaw_access_project
# Updated
# Jun 6
# •
# 3.02k
# •
# 158
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 31.6k
# •
# 8.43k
# microsoft/rStar-Coder
# Updated
# 3 days ago
# •
# 5.38k
# •
# 131
# interstellarninja/hermes_reasoning_tool_use
# Updated
# about 7 hours ago
# •
# 275
# •
# 29
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 777 models
# •
# 3.66k followers
# AI at Meta
# Enterprise
# company
# •
# 2.18k models
# •
# 6.9k followers
# Amazon
# company
# •
# 20 models
# •
# 3.31k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 21.5k followers
# Intel
# company
# •
# 220 models
# •
# 2.75k followers
# Microsoft
# company
# •
# 409 models
# •
# 13.8k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 170 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,366
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,901
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,355
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,785
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,917
# Fast tokenizers optimized for research & production
# TRL
# 14,711
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,174
# State-of-the-art ML running directly in your browser
# smolagents
# 21,489
# Smol library to build great agents in Python
# PEFT
# 19,103
# Parameter-efficient finetuning for large language models
# Datasets
# 20,402
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,352
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,958
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Team & Enterprise Hub
# Scale your organization with the world’s leading AI platform
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Inference Providers
# Enable organization billing for Inference Providers, monitor usage with analytics, and manage spending limits.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 21.5k followers
# Shopify
# Enterprise
# company
# •
# 500 followers
# AMD
# Enterprise
# company
# •
# 154 models
# •
# 1.69k followers
# JetBrains
# Team
# company
# •
# 11 models
# •
# 630 followers
# Together
# Team
# company
# •
# 33 models
# •
# 648 followers
# Xsolla
# Enterprise
# company
# •
# 153 followers
# Toyota Research Institute
# Team
# company
# •
# 10 models
# •
# 131 followers
# TNG Technology Consulting GmbH
# Team
# company
# •
# 5 models
# •
# 254 followers
# FuriosaAI
# Team
# company
# •
# 9 models
# •
# 93 followers
# Technology Innovation Institute
# Team
# company
# •
# 104 models
# •
# 1.51k followers
# HyperCLOVA X
# Team
# company
# •
# 4 models
# •
# 447 followers
# HiddenLayer
# Team
# company
# •
# 1 model
# •
# 76 followers
# Roblox Corporation
# Enterprise
# company
# •
# 5 models
# •
# 253 followers
# Lightricks
# Team
# company
# •
# 18 models
# •
# 1.17k followers
# NVIDIA
# Enterprise
# +
# company
# •
# 441 models
# •
# 32.6k followers
# AI at Meta
# Enterprise
# company
# •
# 2.18k models
# •
# 6.9k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 253 followers
# Arm
# Enterprise
# company
# •
# 241 followers
# Qwen
# Team
# company
# •
# 325 models
# •
# 39.6k followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 303 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 166 followers
# Jusbrasil
# Team
# company
# •
# 100 followers
# creditkarma
# Enterprise
# company
# •
# 77 followers
# Aledade Inc
# Enterprise
# +
# company
# •
# 72 followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 170 followers
# MiniMax
# Team
# company
# •
# 10 models
# •
# 1.58k followers
# Liquid AI
# Team
# company
# •
# 8 models
# •
# 397 followers
# Twelve Labs
# Team
# company
# •
# 50 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 53.8k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 305 followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 570 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# ServiceNow
# Enterprise
# company
# •
# 2 models
# •
# 530 followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 123 followers
# Fidelity Investments
# Enterprise
# company
# •
# 154 followers
# IBM Granite
# Team
# company
# •
# 125 models
# •
# 2.09k followers
# BAIDU
# Team
# company
# •
# 25 models
# •
# 891 followers
# H2O.ai
# Team
# company
# •
# 71 models
# •
# 436 followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# LinkedIn
# Enterprise
# company
# •
# 69 followers
# Novo Nordisk R&ED
# Team
# company
# •
# 47 followers
# BCG X
# Team
# company
# •
# 40 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# By
# orrzohar
# July 23, 2025
# •
# 9
# Community Articles
# view all
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 7 days ago
# •
# 100
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 6 days ago
# •
# 56
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 5 days ago
# •
# 43
# Test-Driving the LLMD Inference Engine by ZML 🚀
# By
# erikkaum
# •
# 5 days ago
# •
# 21
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 4 days ago
# •
# 15
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 1 day ago
# •
# 12
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 15 days ago
# •
# 31
# 5 Things You Need to Know About Moonshot AI and Kimi K2, the New #1 model on the Hub
# By
# fdaudens
# and 1 other
# •
# 8 days ago
# •
# 19
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 98
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 190
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 21 days ago
# •
# 14
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 13 days ago
# •
# 44
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 632
# Probabilistic Fractal Activation Function (P-FAF) and Its Advantages Over Traditional Word Vectorization
# By
# TuringsSolutions
# •
# Feb 8, 2024
# •
# 14
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 279
# Image compositing with diffusers
# By
# OzzyGT
# •
# 6 days ago
# •
# 4
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 130
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 317
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 21 days ago
# •
# 70
# RealPerformance, A Dataset of Language Model Business Compliance Issues
# By
# davidberenstein1957
# and 1 other
# •
# 2 days ago
# •
# 4
# Fast LoRA inference for Flux with Diffusers and PEFT
# By
# sayakpaul
# July 23, 2025
# •
# 2
# Arc Virtual Cell Challenge: A Primer
# By
# FL33TW00D-HF
# July 18, 2025
# •
# 35
# Consilium: When Multiple LLMs Collaborate
# By
# azettl
# July 17, 2025
# guest
# •
# 14
# Back to The Future: Evaluating AI Agents on Predicting Future Events
# By
# vinid
# July 17, 2025
# guest
# •
# 25
# Five Big Improvements to Gradio MCP Servers
# By
# freddyaboulton
# July 17, 2025
# •
# 18
# Seq vs Seq: the Ettin Suite of Paired Encoders and Decoders
# By
# orionweller
# July 16, 2025
# •
# 43
# Migrating the Hub from Git LFS to Xet
# By
# jsulz
# July 15, 2025
# •
# 23
# Asynchronous Robot Inference: Decoupling Action Prediction and Execution
# By
# fracapuano
# July 10, 2025
# •
# 36
# ScreenEnv: Deploy your full stack Desktop Agent
# By
# A-Mahla
# July 10, 2025
# •
# 50
# Building the Hugging Face MCP Server
# By
# evalstate
# July 10, 2025
# •
# 48
# Reachy Mini - The Open-Source Robot for Today's and Tomorrow's AI Builders
# By
# thomwolf
# July 9, 2025
# •
# 599
# Creating custom kernels for the AMD MI300
# By
# ror
# July 9, 2025
# •
# 40
# Upskill your LLMs with Gradio MCP Servers
# By
# freddyaboulton
# July 9, 2025
# •
# 17
# SmolLM3: smol, multilingual, long-context reasoner
# By
# loubnabnl
# July 8, 2025
# •
# 574
# Previous
# 1
# 2
# 3
# ...
# 44
# Next
# Community Articles
# Sort:
# 		Trending
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 7 days ago
# •
# 100
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 6 days ago
# •
# 56
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 5 days ago
# •
# 43
# Test-Driving the LLMD Inference Engine by ZML 🚀
# By
# erikkaum
# •
# 5 days ago
# •
# 21
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 4 days ago
# •
# 15
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 1 day ago
# •
# 12
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 15 days ago
# •
# 31
# 5 Things You Need to Know About Moonshot AI and Kimi K2, the New #1 model on the Hub
# By
# fdaudens
# and 1 other
# •
# 8 days ago
# •
# 19
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 98
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 190
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 21 days ago
# •
# 14
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 13 days ago
# •
# 44
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 632
# Probabilistic Fractal Activation Function (P-FAF) and Its Advantages Over Traditional Word Vectorization
# By
# TuringsSolutions
# •
# Feb 8, 2024
# •
# 14
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 279
# Image compositing with diffusers
# By
# OzzyGT
# •
# 6 days ago
# •
# 4
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 130
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 317
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 21 days ago
# •
# 70
# RealPerformance, A Dataset of Language Model Business Compliance Issues
# By
# davidberenstein1957
# and 1 other
# •
# 2 days ago
# •
# 4
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community discussions
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Static html space direct link gives 404
# Spaces
# 3
# 19
# July 23, 2025
# Best option to compare small voice clips
# Beginners
# 1
# 6
# July 23, 2025
# Exception has occurred: StopIteration exception: no description File "/home/swaraj/sj_code/langchain_hf_demo/LLMs/hf_demo.py", line 14, in <module> result = model.invoke("What is the capital of India?") StopIteration:
# Beginners
# 1
# 7
# July 23, 2025
# Why have my space and account been inexplicably banned?
# Site Feedback
# 5
# 64
# July 22, 2025
# RuntimeError: CUDA error: named symbol not found when using TorchAoConfig with Qwen2.5-VL-7B-Instruct model
# 🤗Transformers
# 2
# 8
# July 23, 2025
# RAG Debugging Is 10x Worse Than I Thought — So I Wrote a Semantic Firewall Instead
# Intermediate
# 0
# 8
# July 23, 2025
# Invalid credentials in Authorization header... Please help
# Beginners
# 3
# 24
# July 22, 2025
# Getting Value-error over and over again while trying to run the lfm2-1.2b model
# Beginners
# 1
# 10
# July 23, 2025
# Context Engineering: A frontier, first-principles handbook with concepts from over 1400 research papers
# Beginners
# 0
# 9
# July 23, 2025
# As of transformers v4.44, default chat template is no longer allowed
# 🤗Transformers
# 3
# 4028
# July 23, 2025
# Best model to fine-tune for code explanation and debugging assistant (zero-cost deployment goal)
# Models
# 2
# 18
# July 22, 2025
# "400 'metadata' is required" on same account username, same Space name
# Spaces
# 2
# 15
# July 22, 2025
# Do you we need to tell the llm the MCP client functions it can call in every prompt or just system prompt
# Intermediate
# 2
# 18
# July 23, 2025
# Loading a dataset cached in a LocalFileSystem is not supported
# 🤗Datasets
# 3
# 685
# July 23, 2025
# How to calculate effective batch size while using DDP?
# Beginners
# 2
# 12
# July 21, 2025
# Cannot import name 'Wav2Vec2Processor'
# 🤗Transformers
# 2
# 7
# July 22, 2025
# My stop working
# Beginners
# 2
# 6
# July 23, 2025
# Recommendations for ML courses
# Beginners
# 3
# 31
# July 20, 2025
# N8n on Hugging Face Space: getaddrinfo ENOTFOUND api.telegram.org Connection Error
# Spaces
# 13
# 171
# July 23, 2025
# Combining multi-scale projections with dynamic adjustments based on KL divergence to correct biases. Innovation?
# Intermediate
# 0
# 6
# July 22, 2025
# What architecture enables pose-consistent, photorealistic virtual outfit changes?
# Models
# 1
# 16
# July 22, 2025
# Dall E Mini clogged since 5 days
# Models
# 1
# 13
# July 22, 2025
# How long does image generation with black-forest-labs/FLUX.1-dev take?
# Models
# 4
# 14
# July 22, 2025
# Dataset scripts are no longer supported
# 🤗Datasets
# 4
# 78
# July 22, 2025
# How to get the grad norm of a deepspeed-zero3 model after accelerator.prepare()
# 🤗Accelerate
# 2
# 669
# July 23, 2025
# Proper way of saving/loading models for complex workflows
# 🤗Transformers
# 2
# 8
# July 22, 2025
# Hello, my account has been blocked?
# Beginners
# 7
# 82
# July 23, 2025
# Fine tuning and it's effects on model safety
# Models
# 4
# 32
# July 23, 2025
# How do I create Datasets from PDF files?
# Beginners
# 7
# 1322
# July 23, 2025
# Getting-error-attributeerror-inferenceclient-object-has-no-attribute-post
# Beginners
# 1
# 9
# July 22, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Spark
# New
# Build and deploy intelligent apps
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# Sponsor
# 51.7k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 1
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 147k
# 29.8k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.9k
# 6.1k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.4k
# 2.9k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 19.1k
# 2k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 9k
# 1.2k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 3k
# 563
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# Makefile
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 335 repositories
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 147,367
# Apache-2.0
# 29,750
# 1,053
# (2 issues need help)
# 818
# Updated
# Jul 23, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 132
# Apache-2.0
# 13
# 11
# 11
# Updated
# Jul 23, 2025
# optimum-onnx
# Public
# 🤗 Optimum ONNX: Export your model to ONNX and run inference with ONNX Runtime
# huggingface/optimum-onnx’s past year of commit activity
# Python
# 10
# Apache-2.0
# 2
# 3
# 0
# Updated
# Jul 23, 2025
# optimum-executorch
# Public
# 🤗 Optimum ExecuTorch
# huggingface/optimum-executorch’s past year of commit activity
# Python
# 58
# Apache-2.0
# 15
# 13
# 10
# Updated
# Jul 23, 2025
# optimum-neuron
# Public
# Easy, fast and very cheap training and inference on AWS Trainium and Inferentia chips.
# huggingface/optimum-neuron’s past year of commit activity
# Jupyter Notebook
# 235
# Apache-2.0
# 79
# 16
# 5
# Updated
# Jul 23, 2025
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# huggingface/datasets’s past year of commit activity
# Python
# 20,402
# Apache-2.0
# 2,867
# 827
# (2 issues need help)
# 111
# Updated
# Jul 23, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 16,068
# Apache-2.0
# 2,199
# 355
# 194
# Updated
# Jul 23, 2025
# text-embeddings-inference
# Public
# A blazing fast inference solution for text embeddings models
# huggingface/text-embeddings-inference’s past year of commit activity
# Rust
# 3,824
# Apache-2.0
# 288
# 129
# 15
# Updated
# Jul 23, 2025
# huggingface_hub
# Public
# The official Python client for the Huggingface Hub.
# huggingface/huggingface_hub’s past year of commit activity
# Python
# 2,785
# Apache-2.0
# 762
# 171
# (4 issues need help)
# 18
# Updated
# Jul 23, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,901
# Apache-2.0
# 6,132
# 524
# (12 issues need help)
# 202
# Updated
# Jul 23, 2025
# View all repositories
# People
# View all
# Sponsoring
# Top languages
# Python
# Jupyter Notebook
# TypeScript
# Rust
# MDX
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# GitHub Sponsor
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 587 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 67,378 followers
# 10h
# Edited
# Report this post
# 🔥🆕ObjectClear, an object removal model capable of eliminating target object and its effects (shadow etc.)
#
# Object Clear app on
# Hugging Face
# :
# https://lnkd.in/g8NgaSkB
# …more
# 74
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,378 followers
# 11h
# Edited
# Report this post
# 🎉 Big news! Google Colab now comes with Gradio pre-installed (v5.38)!
#
# No more pip install gradio needed - just import and start building AI apps instantly.
#
# 🙌 Thanks to
# Chris Perry
# and the whole
# Google Colab
# team for making Gradio more accessible to millions of developers worldwide!
# 615
# 24 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Raushan Turganbay
# ML engineer at 🤗 | Multimodality and Generation |  Erasmus Mundus MSc
# 1d
# Report this post
# 🚀  Big big news for multimodal devs! The transformers ↔️ vLLM integration just leveled up: Vision-Language Models are now supported out of the box
#
# If the model is integrated into Transformers, you can now run it directly with vLLM — no need to rewrite or duplicate code. Just plug it in and go. Zero extra effort
#
# Performance might differ model to model (we’re working on that!), but functional support is guaranteed
#
# Curious how to serve Transformers models with vLLM? Full docs here 👉
# https://lnkd.in/d-KjqbmU
# #multimodal
# #transformers
# #vLLM
# #VLM
# #opensource
# 382
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 1d
# Edited
# Report this post
# 🔥 Vibe coding for data science with Kimi K2 - a step-by-step tutorial you can run for free!
#
# I'm excited to share a new approach to working with unstructured datasets, powered by the
# Hugging Face
# Hub and open models!
# https://lnkd.in/dBwFrS_g
# 177
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,378 followers
# 4d
# Edited
# Report this post
# Mixture of Experts? No no, Roundtable of Experts! Meet CONSILIUM - Where AI Models Debate Around a Table! Amazing results! 👇 Let's learn more
#
# 📊 THE VALIDATION
# Microsoft proved why multi-agent setup matters:
# - AI panel of "doctors": 85.5% accuracy / Human doctors: 20% accuracy
# - 4X BETTER at diagnosis
# - While CUTTING costs
# More here: AI Diagnostic Orchestrator (MAI-DxO) :
# https://lnkd.in/dF-fDzcM
# 🎰 WHAT IS CONSILIUM?
# Built during Agents-MCP hackathon, Consilium seats LLMs around a visual poker table where they:
# - Debate complex questions with distinct roles
# - Research using 5+ external sources
# - Reach consensus through structured discussion
# - Show real-time "thinking" bubbles
# It's like having an expert panel on demand ⚡
#
# 🎭 The breakthrough? Each LLM gets a personality:
# - 🔥 Expert Advocate: Passionate specialist
# - 🔍 Critical Analyst: Finds flaws & risks
# - 🎯 Strategic Advisor: Practical solutions
# - 📚 Research Specialist: Deep domain knowledge
# - ⚡ Innovation Catalyst: Challenges conventional thinking
# Real and longer debate = better decisions 🧠
#
# 🌐 RESEARCH AGENT MAGIC : When models need facts, a dedicated research agent joins the table and searches following sources --
# - 🔍 Web Search
# - 📖 Wikipedia
# - 📄 arXiv papers
# - 💻 GitHub
# - 📈 SEC EDGAR
# Recorded demo:
# https://lnkd.in/gMzrgqJK
# 🛠️ TECHNICAL BRILLIANCE -- Built as :
# - A Gradio UI (that poker table is 🔥)
# - MCP server for integrating Consilium in your workflows
# - A Custom Gradio component
# - Session-based state management
# - Real-time visual updates
# Developer experience = 10/10 ✨
# MCP demo:
# https://lnkd.in/gaEAVUMS
# 💡REAL-WORLD APPLICATIONS -- Imagine using this for:
# - 🏥 Medical diagnosis (already proven)
# - 💼 Business strategy decisions (ooh 🤩)
# - 🔬 Research paper analysis
# - ⚖️ Legal case evaluation
# Any complex decision = perfect use case 🎯
# Play with the App:
# https://lnkd.in/gK-w6sYA
# 🔥 Consilium is built by
# Andreas Zettl
# 📖 READ MORE ON CONSILIUM in this
# Hugging Face
# Report --
# Consilium: When Multiple LLMs Collaborate:
# https://lnkd.in/gmT65peC
# …more
# 337
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# 1,019,777 followers
# 4d
# Edited
# Report this post
# You can now seamlessly switch between providers like
# Groq
# ,
# SambaNova
# ,
# Together AI
# ,
# Cerebras Systems
# and more and LLMs like Kimi K2, DeepSeek R1 and 6000+ models using the OpenAI client 🤗
#
# Time to build is now! 🔥
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 5d
# You asked we delivered! Hugging Face Inference Providers is now fully OpenAI client compatible! 🔥
#
# Simply append the provider name to the model ID and.. that's it!
#
# Read more here:
# https://lnkd.in/eNsZsmci
# OpenAI client is arguably the most used client when it comes to LLMs, so getting this right is a big milestone for the team! 🤗
# 73
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 5d
# Report this post
# Fighting with prompts for data augmentation is a thing of the past.
#
#
# Here's a workflow where
# Hugging Face
# AISheets handles few-shot and context engineering for you!
#
#
# 1. Load your dataset (csv, parquet, Excel, HF hub)
# 2. Write a VERY simple prompt (e.g., categorize the following text).
# 3. Generate a few rows and inspect the results.  Even SOTA models like Kimi K2 will make mistakes.
# 4. While inspecting the results, mark good examples with the thumbs-up
#  button.
# 5. Regenerate and profit!
#
# Under the hood, AISheets will manage the context in the  prompt (adding few-shot examples and web docs if search is enabled).
#
# This will instantly improve the quality of the generated cells!
#
# Check the dataset I've built in the comments.
#
# If you like this, try it out and leave ❤️ to support us:
# https://lnkd.in/dVu2f2SB
# …more
# 70
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# 1,019,777 followers
# 5d
# Report this post
# Excited to bring the collective power of Inference Providers to
# Pydantic
# AI 🔥
#
# Go check it out!
# Pydantic
# 12,310 followers
# 6d
# Pydantic AI now supports
# Hugging Face
# as a provider! Hugging Face (
# https://huggingface.co/
# ) is an AI platform with all major open source models, datasets, MCPs, and demos.
#
# You can use it to run open source models like DeepSeek R1 on scalable serverless infrastructure. They have a free tier allowance so you can test it out.
#
# Thanks to the Hugging Face team (
# Célina Hanouti
# ) for this great contribution. For more details, check out the docs (
# https://lnkd.in/eTwF-dHi
# )
# Hugging Face – The AI community building the future.
# huggingface.co
# 94
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 6d
# Report this post
# New Tutorial in the MCP Course! This tutorial walks you through building a tiny agents application using AMD hardware.
#
# 🔗
# https://lnkd.in/efv9bk8H
# - You can use  Neural Processing Unit (NPU) and integrated GPU (iGPU) from AMD
# - Sets up local file MCP for dealing with sensitive files
#
# It's sick to see local assistants make it on to even more hardware.
# 486
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 1w
# Report this post
# BOOOM! Both VLMs and LLMs now have a baked-in http server w/ OpenAI spec compatible API in transformers
#
# Launch it with `transformers serve` and connect your favorite apps.
#
# Here I'm running @OpenWebUI with local transformers.
#
# LLM, VLM, tool calling is in, STT & TTS coming soon!
# …more
# 475
# 20 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nGet started with Inference in seconds 🚀\nReachy Mini: The Open Robot for AI Builders\nWelcome Cohere on the Hub 🔥\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nmoonshotai/Kimi-K2-Instruct\nUpdated\n1 day ago\n•\n195k\n•\n1.76k\nQwen/Qwen3-235B-A22B-Instruct-2507\nUpdated\n2 days ago\n•\n1.32k\n•\n422\nQwen/Qwen3-Coder-480B-A35B-Instruct\nUpdated\nabout 10 hours ago\n•\n403\nmistralai/Voxtral-Mini-3B-2507\nUpdated\nabout 6 hours ago\n•\n46.4k\n•\n423\nHiDream-ai/HiDream-E1-1\nUpdated\n6 days ago\n•\n180\n•\n147\nBrowse 1M+ models\nSpaces\nRunning\n10.7k\n10.7k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\nMCP\n1.02k\n1.02k\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nRunning\n2.32k\n2.32k\nAnycoder\n🏢\nGenerate modern HTML/CSS/JS code for web apps\nRunning\non\nZero\nMCP\n1.28k\n1.28k\nWan2.1 Fast\n🎥\nGenerate animated videos from images\nRunning\n1.01k\n1.01k\nRealistic Text To Speech Unlimited\n🔥\nFree Text-To-Speech generator with Emotion control (OpenAI)\nBrowse 400k+ applications\nDatasets\nNousResearch/Hermes-3-Dataset\nUpdated\n12 days ago\n•\n3.07k\n•\n209\ncommon-pile/caselaw_access_project\nUpdated\nJun 6\n•\n3.02k\n•\n158\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n31.6k\n•\n8.43k\nmicrosoft/rStar-Coder\nUpdated\n3 days ago\n•\n5.38k\n•\n131\ninterstellarninja/hermes_reasoning_tool_use\nUpdated\nabout 7 hours ago\n•\n275\n•\n29\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n777 models\n•\n3.66k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.18k models\n•\n6.9k followers\nAmazon\ncompany\n•\n20 models\n•\n3.31k followers\nGoogle\nEnterprise\ncompany\n•\n1.04k models\n•\n21.5k followers\nIntel\ncompany\n•\n220 models\n•\n2.75k followers\nMicrosoft\ncompany\n•\n409 models\n•\n13.8k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n170 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n317 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n147,366\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,901\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,355\nSafe way to store/distribute neural network weights\nHub Python Library\n2,785\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,917\nFast tokenizers optimized for research & production\nTRL\n14,711\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,174\nState-of-the-art ML running d ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
#
# **Hugging Face** is the AI community building the future. We provide a collaborative platform for machine learning enthusiasts, researchers, and businesses to explore cutting-edge models, datasets, and applications. Our mission is to make AI development more accessible and to foster an open-source landscape where innovation thrives.
#
# ---
#
# ## What We Offer
#
# ### **Explore and Collaborate**
# - **Models & Datasets:** Over 1 million models and 250,000 datasets are available for users to explore, share, and utilize.
# - **Spaces:** Create diverse applications with ease, from text generation to video animations, all running on our robust infrastructure.
# - **Open Source Tools:** We provide the foundation for machine learning tooling that includes state-of-the-art libraries such as Transformers, Diffusers, and much more.
#
# ### **Enterprise Solutions**
# - **Team & Enterprise Support:** Tailored solutions for over 50,000 organizations including industry giants like Google, Microsoft, and Amazon.
# - **Compute Solutions:** Deploy models and applications effortlessly with optimized inference endpoints starting as low as $0.60/hour.
#
# ---
#
# ## Our Culture
#
# At Hugging Face, we believe in fostering a strong community of AI enthusiasts and pioneers. Our culture is driven by collaboration, innovation, and openness. We emphasize:
# - **Community Engagement:** We encourage users to collaborate, share ideas, and contribute to our vast repository of models and datasets.
# - **Support for Creatives:** Whether you are a seasoned developer or a newcomer, our platform offers the resources needed to enhance your skills and build amazing AI applications.
#
# ---
#
# ## Join Us
#
# **Careers at Hugging Face**
# Become part of a forward-thinking team that is passionate about AI! We are on the lookout for diverse talents who can help elevate our offerings and contribute to our vibrant community.
#
# **Open Positions:**
# - Machine Learning Engineers
# - Software Developers
# - Community Managers
# - Data Scientists
#
# Explore our current job openings and apply to join the mission of democratizing AI for everyone.
#
# ---
#
# ## Get Started
#
# Whether you are looking to build the next big AI application, collaborate with data scientists, or become part of a cutting-edge organization, Hugging Face is your partner on this journey.
#
# **Join the AI Revolution.**
# Visit us at [Hugging Face](https://huggingface.co) and start your journey in AI today!
#
# ---
#
# For inquiries, please reach us through our [contact page](https://huggingface.co/contact) or follow us on our [social media](https://huggingface.co/social).

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ## About Us
# **Hugging Face** is a leading AI community focused on building the future of machine learning through collaboration. Our platform is designed for the machine learning community to come together and work on models, datasets, and applications.
#
# ## Our Offerings
# - **Models**: Browse through a diverse collection of over **1 million models** tailored for various applications.
# - **Datasets**: Access more than **250,000 datasets** suitable for all types of machine learning tasks.
# - **Spaces**: Create and share applications effortlessly with our **10.7k running projects**.
# - **Enterprise Solutions**: Tailored options for organizations including dedicated support and advanced security.
#
# ## Community-Centric Culture
# At Hugging Face, we prioritize community engagement and open collaboration. We believe in:
# - **Open Source**: We’re building the foundation of ML tooling alongside our community.
# - **Innovation**: Leverage cutting-edge technologies like Transformers, Diffusers, and more to stay ahead in AI development.
# - **Support**: Our platform is designed to empower users to build their ML portfolio, share work, and receive feedback.
#
# ## Our Customers
# Hugging Face serves over **50,000 organizations**, including major players such as:
# - **Google**
# - **Microsoft**
# - **Amazon**
# - **Meta**
#
# Each of these enterprises contributes to the creation of countless models and datasets, enhancing their AI capabilities.
#
# ## Career Opportunities
# Join us and become a part of the AI revolution! At Hugging Face, we offer a range of career opportunities for talent interested in artificial intelligence and machine learning. Our team culture fosters growth, creativity, and collaboration.
#
# ### Current Openings
# - Join dynamic teams pushing the boundaries of AI.
# - Work in an environment where your contributions matter and help shape the future.
#
# ## Get Started Today!
# Explore AI applications, collaborate on projects, or simply learn more about machine learning at Hugging Face. Sign up on our website and take your first step into the future of AI!
#
# **Website**: [Hugging Face](https://huggingface.co)
#
# ---
#
# ### Connect With Us
# Join the conversation and community:
# - **[Twitter](https://twitter.com/huggingface)**
# - **[LinkedIn](https://linkedin.com/company/hugging-face)**
# - **[Discord](https://discord.com/invite/huggingface)**
#
# ---
#
# Together, let’s build the future of artificial intelligence!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face: The AI Community Building the Future!
#
# Welcome to Hugging Face, where we don’t just create AI; we give it *hugs*! 🤗 Join our community and step into a world of machine learning marvels, datasets galore, and more models than you can shake a p-value at!
#
# ---
#
# ## 🚀 **What Do We Offer?**
#
# - **1 Million+ Models**: That's right! Our models are as plentiful as coffee in a programmer’s den. From generating HTML/CSS code to realistic text-to-speech (with emotional flair!), our AI powers amazing applications.
#
# - **Datasets, Datasets, Datasets!**: With over 250k datasets available, it’s like a buffet of data where you can feast to your heart's content. Come for the data, stay for the machine learning magic! 🍽️
#
# - **Spaces**: Create your own little corner of the digital universe. With over 10,000 active spaces, you can run everything from deep-sea explorations to cartoon cat animations. 🐳🎥
#
# ---
#
# ## 🤝 **Community Collaboration**
#
# Collaborate on models and applications where machine learning enthusiasts gather to share knowledge:
#
# - Think of us as the ultimate meet-up for AI geeks, nerds, and innovators sharing the secret sauce of modern technology. (No, we’re not talking about ketchup.)
#
# ---
#
# ## **Company Culture**
#
# At Hugging Face, our culture is built on collaboration, openness, and creativity. Forget the cubicles and water cooler chit-chat; here, we roll up our sleeves and dive into brainstorming sessions over coffee (or tea if you’re fancy!).
#
# We’re on a mission to build a future where AI and humans live in harmony, possibly sharing hugs on the weekends! 🤗
#
# ---
#
# ## 🚀 **Join the Next Revolution in AI!**
#
# ### **Careers at Hugging Face**:
# Do you dream in algorithms? Do neural networks make your heart race? **We want you!**
# - **Current Openings**: Besides AI whisperers, we’re looking for passionate individuals who want to shape the future of machine learning.
# - **Perks**: Flexible hours, rewards for innovations, and hugs at every welcome!
#
# ---
#
# ## 💼 **Who Uses Us?**
#
# Over **50,000 organizations** love our platform, including tech giants like Google, Amazon, and Microsoft. Join the ranks of the elite who are shaping the AI landscape!
#
# ---
#
# ### **Get Started Today!**
# Whether you’re a curious customer, a seasoned investor, or a starry-eyed recruit, Hugging Face is your gateway to an AI-powered future. Sign up today for a free trial and let’s build something amazing together!
#
# ---
#
# 📝 **Contact Us**
# Hugging Face is just a click away. Reach out through our website or social media (Twitter, LinkedIn, Discord—wherever you hang out) and let’s chat about AI over a virtual hug!
#
# ---
#
# **Remember: In a world full of chaos, we could all use a little more hugging…especially when it involves building the future!** 🤗💻

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
